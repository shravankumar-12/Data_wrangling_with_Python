# %% [markdown]
# <a href="https://colab.research.google.com/github/shravankumar-12/deeplearningwithCV/blob/main/4SF22RA037_PROGRAM1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ** Program1: Covers Data Collection and Data exploration **- Covering Pandas Basics and Data Cleaning: Use Pandas library to load, clean, and
# preprocess data. Read various data formats, handling missing values, and basic data manipulation
# ** Task1 : Data Collection/Creation** Creating a Dataframe

# %%
import pandas as pd
df=pd.DataFrame(
{
"Name":[
"Braud, Mr. Owens Harris",
"Allen,Mr. William Henry",
"Bonnell, Miss Elizabeth",
],
"Age":[22,35,87],
"Sex":["Male","Male","Female"],
}
)
df
# Out:
#                       Name  Age     Sex
# 0  Braud, Mr. Owens Harris   22    Male
# 1  Allen,Mr. William Henry   35    Male
# 2  Bonnell, Miss Elizabeth   87  Female

# %% [markdown]
# Task 2:Data Collection Extracting only a series in Dataframe. In the exmaple use.extract only "Age" series

# %%
df["Name"]
# Out:
# 0    Braud, Mr. Owens Harris
# 1    Allen,Mr. William Henry
# 2    Bonnell, Miss Elizabeth
# Name: Name, dtype: object

# %% [markdown]
# Task3:Data Collection Create a series "Weight"

# %%
Weight= pd.Series([45,62,78],name="Weight")
Weight
# Out:
# 0    45
# 1    62
# 2    78
# Name: Weight, dtype: int64

# %% [markdown]
# Task 4: Data exploration in a dataframe** Find out the minimum and the maximum of the passenger ages

# %%
old = df["Age"].max()
young=df["Age"].min()
print(old)
print(young)
# Out:
# 87
# 22

# %% [markdown]
# *Task 4: Data exploration *in a series Find out the minimum and the maximum weights of the passengers

# %%
lightest= Weight.min()
heaviest=Weight.max()
print(lightest)
print(heaviest)
# Out:
# 45
# 78

# %% [markdown]
# Task5 : Data exploration: Get complete statistics of numeric data of the dataframe

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   48.000000
# std    34.394767
# min    22.000000
# 25%    28.500000
# 50%    35.000000
# 75%    61.000000
# max    87.000000

# %% [markdown]
# Conclusion
# The program has highlighted the pivotal role played by the Pandas library in Python for data collection and exploration tasks. It has showcased
# Pandas' versatility in effortlessly handling diverse data formats, encompassing CSV, Excel, and SQL databases. Additionally, Pandas provides
# robust methods for effectively managing missing values, ensuring data integrity throughout the preprocessing stage.
